# %%
# ---------- CHECK ----------
def is_valid(board, row, col, num):
    for i in range(9):
        if board[row][i] == num or board[i][col] == num:
            return False

    start_row = row - row % 3
    start_col = col - col % 3

    for i in range(3):
        for j in range(3):
            if board[start_row + i][start_col + j] == num:
                return False

    return True


# ---------- BACKTRACK ----------
def solve(board):
    global backtrack_calls, failures
    backtrack_calls += 1

    for row in range(9):
        for col in range(9):
            if board[row][col] == 0:

                for num in range(1, 10):
                    if is_valid(board, row, col, num):
                        board[row][col] = num

                        if solve(board):
                            return True

                        board[row][col] = 0

                failures += 1
                return False

    return True


# ---------- PRINT ----------
def print_board(board):
    for row in board:
        print(row)


# ---------- BOARDS ----------
boards = [

("Easy", [
[0,0,4,0,3,0,0,5,0],
[6,0,9,4,0,0,0,0,0],
[0,0,5,1,0,0,4,8,9],
[0,0,0,0,6,0,9,3,0],
[3,0,0,8,0,7,0,0,2],
[0,2,6,0,4,0,0,0,0],
[4,5,3,0,0,9,6,0,0],
[0,0,0,0,0,4,7,0,5],
[0,9,0,0,5,0,2,0,0]
]),

("Medium", [
[0,2,0,6,0,8,0,0,0],
[5,8,0,0,0,9,7,0,0],
[0,0,0,0,4,0,0,0,0],
[3,7,0,0,0,0,5,0,0],
[6,0,0,0,0,0,0,0,4],
[0,0,8,0,0,0,0,1,3],
[0,0,0,0,2,0,0,0,0],
[0,0,9,8,0,0,0,3,6],
[0,0,0,3,0,6,0,9,0]
]),

("Hard", [
[5,3,0,0,7,0,0,0,0],
[6,0,0,1,9,5,0,0,0],
[0,9,8,0,0,0,0,6,0],
[8,0,0,0,6,0,0,0,3],
[4,0,0,8,0,3,0,0,1],
[7,0,0,0,2,0,0,0,6],
[0,6,0,0,0,0,2,8,0],
[0,0,0,4,1,9,0,0,5],
[0,0,0,0,8,0,0,7,9]
]),
    
("Very Hard", [
[0,0,0,0,0,0,2,0,0],
[0,8,0,0,0,7,0,9,0],
[6,0,2,0,0,0,5,0,0],
[0,7,0,0,6,0,0,0,0],
[0,0,0,9,0,1,0,0,0],
[0,0,0,0,2,0,0,4,0],
[0,0,5,0,0,0,6,0,3],
[0,9,0,4,0,0,0,7,0],
[0,0,6,0,0,0,0,0,0]
])

]


# ---------- RUN ALL ----------
for name, board in boards:
    print("\n==============================")
    print("Solving:", name)
    print("==============================\n")

    backtrack_calls = 0
    failures = 0

    solve(board)

    print("Solved Sudoku:\n")
    print_board(board)

    print("\nBacktrack calls:", backtrack_calls)
    print("Failures:", failures)
# Out:
# ==============================
# Solving: Easy
# ==============================
#
# Solved Sudoku:
#
# [7, 8, 4, 9, 3, 2, 1, 5, 6]
# [6, 1, 9, 4, 8, 5, 3, 2, 7]
# [2, 3, 5, 1, 7, 6, 4, 8, 9]
# [5, 7, 8, 2, 6, 1, 9, 3, 4]
# [3, 4, 1, 8, 9, 7, 5, 6, 2]
# [9, 2, 6, 5, 4, 3, 8, 7, 1]
# [4, 5, 3, 7, 2, 9, 6, 1, 8]
# [8, 6, 2, 3, 1, 4, 7, 9, 5]
# [1, 9, 7, 6, 5, 8, 2, 4, 3]
#
# Backtrack calls: 229
# Failures: 179
#
# ==============================
# Solving: Medium
# ==============================
#
# Solved Sudoku:
#
# [1, 2, 3, 6, 7, 8, 9, 4, 5]
# [5, 8, 4, 2, 3, 9, 7, 6, 1]
# [9, 6, 7, 1, 4, 5, 3, 2, 8]
# [3, 7, 2, 4, 6, 1, 5, 8, 9]
# [6, 9, 1, 5, 8, 3, 2, 7, 4]
# [4, 5, 8, 7, 9, 2, 6, 1, 3]
# [8, 3, 6, 9, 2, 4, 1, 5, 7]
# [2, 1, 9, 8, 5, 7, 4, 3, 6]
# [7, 4, 5, 3, 1, 6, 8, 9, 2]
#
# Backtrack calls: 2251
# Failures: 2193
#
# ==============================
# Solving: Hard
# ==============================
#
# Solved Sudoku:
#
# [5, 3, 4, 6, 7, 8, 9, 1, 2]
# [6, 7, 2, 1, 9, 5, 3, 4, 8]
# [1, 9, 8, 3, 4, 2, 5, 6, 7]
# [8, 5, 9, 7, 6, 1, 4, 2, 3]
# [4, 2, 6, 8, 5, 3, 7, 9, 1]
# [7, 1, 3, 9, 2, 4, 8, 5, 6]
# [9, 6, 1, 5, 3, 7, 2, 8, 4]
# [2, 8, 7, 4, 1, 9, 6, 3, 5]
# [3, 4, 5, 2, 8, 6, 1, 7, 9]
#
# Backtrack calls: 4209
# Failures: 4157
#
# ==============================
# Solving: Very Hard
# ==============================
#
# Solved Sudoku:
#
# [9, 5, 7, 6, 1, 3, 2, 8, 4]
# [4, 8, 3, 2, 5, 7, 1, 9, 6]
# [6, 1, 2, 8, 4, 9, 5, 3, 7]
# [1, 7, 8, 3, 6, 4, 9, 5, 2]
# [5, 2, 4, 9, 7, 1, 3, 6, 8]
# [3, 6, 9, 5, 2, 8, 7, 4, 1]
# [8, 4, 5, 7, 9, 2, 6, 1, 3]
# [2, 9, 1, 4, 3, 6, 8, 7, 5]
# [7, 3, 6, 1, 8, 5, 4, 2, 9]
#
# Backtrack calls: 1070593
# Failures: 1070531
